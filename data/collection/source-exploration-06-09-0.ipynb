# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.rogerebert.com/reviews')

print(BeautifulSoup(res.content).get_text())
# Out:
# Reviews | Roger Ebert
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Great Movies
#
#
#
# Collections
#
#
#
# TV/Streaming
#
#
#
# Interviews
#
#
#
# Movie Reviews
#
#
#
# Chaz's Journal
#
#
#
# Contributors
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
# All movie reviews
#
#
#
#
#
#
#
#
#
#
#
#
# Filter movie reviews
#
# Reset filters
#
#
#
#
#
# Title
#
#
#
#
#
# Order by
#
#
# Title
# Newest by release date
# Oldest by release date
# Newest published
# Oldest published
# Highest rated
# Lowest rated
#
#
#
#
# Only Great Movies
#
#
#
#
#
# Release date
#
#
# 1914
# 1915
# 1916
# 1917
# 1918
# 1919
# 1920
# 1921
# 1922
# 1923
# 1924
# 1925
# 1926
# 1927
# 1928
# 1929
# 1930
# 1931
# 1932
# 1933
# 1934
# 1935
# 1936
# 1937
# 1938
# 1939
# 1940
# 1941
# 1942
# 1943
# 1944
# 1945
# 1946
# 1947
# 1948
# 1949
# 1950
# 1951
# 1952
# ...

# %%
soup = BeautifulSoup(res.content)

# %%
base_url = 'https://www.rogerebert.com'

# %%
# identify review card
card = soup.find('div', class_='review-stack')

# %%
card.find('a').get('href')
# Out:
# '/reviews/blue-jean-movie-review-2023'

# %%
# test url access
print(base_url+card.find('a').get('href'))
# Out:
# https://www.rogerebert.com/reviews/blue-jean-movie-review-2023

# %%
# author
card.find('h6').get_text(strip=True)
# Out:
# 'Monica Castillo'

# %%
# movie title
card.find('h5').get_text(strip=True)
# Out:
# 'Blue Jean'

# %%
# get review score
score = 0
for star in card.find('span').find_all('i'):
    if star.get('title') == 'star-full':
        score +=1
    elif star.get('title') == 'star-half':
        score +=.5
    print(star.get('title'))
print(f'score: {score}')
# Out:
# star-full
# star-full
# star-full
# star-half
# score: 3.5

# %%
def collect_ebert_reviews(checkpoint=None):
    """Get titles, links, and scores from reviews page of rogerebert.com"""
    
    review_url = 'https://www.rogerebert.com/reviews'
    base_url = 'https://www.rogerebert.com'
    
    try:
        res = requests.get(review_url)
    except:
        return None
    
    if res.status_code != 200:
        return None
    
    soup = BeautifulSoup(res.content)
    reviews = soup.find_all('div', class_='review-stack')
    
    review_list = []
    
    for review in reviews:
        review_data = {}
        
        review_data['title'] = review.find('h5').get_text(strip=True)
        if review_data['title'] == checkpoint:
            return review_list
        
        review_data['author'] = review.find('h6').get_text(strip=True)
        review_data['url'] = base_url + review.find('a').get('href')
                
        score_stars = review.find('span').find_all('i')
        score = 0
        for star in score_stars:
            if star.get('title') == 'star-full':
                score +=1
            elif star.get('title') == 'star-half':
                score +=.5
        
        if score == 0:
            continue
            
        review_data['score'] = score
        review_list.append(review_data)

    return review_list

# %%
collect_ebert_reviews()
# Out:
# [{'title': 'Blue Jean',
#   'author': 'Monica Castillo',
#   'url': 'https://www.rogerebert.com/reviews/blue-jean-movie-review-2023',
#   'score': 3.5},
#  {'title': "Flamin' Hot",
#   'author': 'Monica Castillo',
#   'url': 'https://www.rogerebert.com/reviews/flamin-hot-movie-review-2023',
#   'score': 2},
#  {'title': 'Transformers: Rise of the Beasts',
#   'author': 'Christy Lemire',
#   'url': 'https://www.rogerebert.com/reviews/transformers-rise-of-the-beasts-movie-review-2023',
#   'score': 2.5},
#  {'title': 'Brooklyn 45',
#   'author': "Sheila O'Malley",
#   'url': 'https://www.rogerebert.com/reviews/brooklyn-45-movie-review-2023',
#   'score': 3},
#  {'title': 'Shin Kamen Rider',
#   'author': 'Simon Abrams',
#   'url': 'https://www.rogerebert.com/reviews/shin-kamen-rider-movie-review-2023',
#   'score': 3.5},
#  {'title': 'The Angry Black Girl and Her Monster',
#   'author': 'Peyton Robinson',
# ...

# %%
# caught list from _, most recently evaluated expression
movie_list = _

# %%
movie_list
# Out:
# [{'title': 'Blue Jean',
#   'author': 'Monica Castillo',
#   'url': 'https://www.rogerebert.com/reviews/blue-jean-movie-review-2023',
#   'score': 3.5},
#  {'title': "Flamin' Hot",
#   'author': 'Monica Castillo',
#   'url': 'https://www.rogerebert.com/reviews/flamin-hot-movie-review-2023',
#   'score': 2},
#  {'title': 'Transformers: Rise of the Beasts',
#   'author': 'Christy Lemire',
#   'url': 'https://www.rogerebert.com/reviews/transformers-rise-of-the-beasts-movie-review-2023',
#   'score': 2.5},
#  {'title': 'Brooklyn 45',
#   'author': "Sheila O'Malley",
#   'url': 'https://www.rogerebert.com/reviews/brooklyn-45-movie-review-2023',
#   'score': 3},
#  {'title': 'Shin Kamen Rider',
#   'author': 'Simon Abrams',
#   'url': 'https://www.rogerebert.com/reviews/shin-kamen-rider-movie-review-2023',
#   'score': 3.5},
#  {'title': 'The Angry Black Girl and Her Monster',
#   'author': 'Peyton Robinson',
# ...

# %%
url = 'https://www.rogerebert.com/reviews/shin-kamen-rider-movie-review-2023'

# %%
res = requests.get(url)

# %%
soup = BeautifulSoup(res.content)

# %%
sections = soup.find_all('section', class_='page-content--block_editor-content')

# %%
for sec in sections:
    print(sec.get_text())
# Out:
# It takes a moment for the Japanese superhero adventure “Shin Kamen Rider” to find a rhythm and stick to it. Writer/director Hideaki Anno (“Neon Genesis Evangelion”) throws a lot at viewers during the movie’s preliminary half hour or so, but it all reflects the optimistic character of motorcyclist hero Takeshi Hongo (Sosuke Ikematsu), who transforms into the grasshopper-themed robot biker Kamen Rider. There’s also the movie’s poorly-rendered special effects, glassy-looking handheld photography, hard cuts, and off-kilter camera blocking. Most of these choices are deliberate, just like in both “Shin Godzilla” and “Shin Ultraman,” which Anno co-created with director/co-writer/special-effects supervisor Shinji Higuchi. “Shin Kamen Rider” looks like the cheapest (to make) of the three movies, so this much unusual style might initially seem more like a bug than a feature. Eventually, this outstanding reboot’s most generic elements appear subordinate to the title character’s deranged, boyish
# ...

# %%
tags = soup.find_all('div', class_='tags--tag')

# %%
for tag in tags:
    print(tag.get_text(strip=True))
# Out:
# Thriller
# Science Fiction
# Action

# %%
def collect_ebert_review_details(url):
    """Collected detailed information from a review on rogerebert.com"""
    
    try:
        res = requests.get(url)
    except:
        return None
    
    if res.status_code != 200:
        return None
    
    soup = BeautifulSoup(res.content)    
    
    details = {}
    
    article = []
    text_blocks = soup.find_all('section', class_='page-content--block_editor-content')
    for block in text_blocks:
        article.append(block.get_text(strip=True))
        
    details['review_text'] = ' '.join(article)
    
    tag_list = []
    tags = soup.find_all('div', class_='tags--tag')
    for tag in tags:
        tag_list.append(tag.get_text(strip=True))
        
    details['tags'] = tag_list
    
    return details

# %%
collect_ebert_review_details(res)
# Out:
# {'review_text': 'It takes a moment for the Japanese superhero adventure “Shin Kamen Rider” to find a rhythm and stick to it. Writer/directorHideaki Anno(“Neon Genesis Evangelion”) throws a lot at viewers during the movie’s preliminary half hour or so, but it all reflects the optimistic character of motorcyclist hero Takeshi Hongo (Sosuke Ikematsu), who transforms into the grasshopper-themed robot biker Kamen Rider.There’s also the movie’s poorly-rendered special effects, glassy-looking handheld photography, hard cuts, and off-kilter camera blocking. Most of these choices are deliberate, just like in both “Shin Godzilla” and “Shin Ultraman,” which Anno co-created with director/co-writer/special-effects supervisorShinji Higuchi. “Shin Kamen Rider” looks like the cheapest (to make) of the three movies, so this much unusual style might initially seem more like a bug than a feature. Eventually, this outstanding reboot’s most generic elements appear subordinate to the title character’s der
# ...

# %%
url = 'https://www.rogerebert.com/reviews/shin-kamen-rider-movie-review-2023'
collect_ebert_review_details(url)
# Out:
# {'review_text': 'It takes a moment for the Japanese superhero adventure “Shin Kamen Rider” to find a rhythm and stick to it. Writer/directorHideaki Anno(“Neon Genesis Evangelion”) throws a lot at viewers during the movie’s preliminary half hour or so, but it all reflects the optimistic character of motorcyclist hero Takeshi Hongo (Sosuke Ikematsu), who transforms into the grasshopper-themed robot biker Kamen Rider.There’s also the movie’s poorly-rendered special effects, glassy-looking handheld photography, hard cuts, and off-kilter camera blocking. Most of these choices are deliberate, just like in both “Shin Godzilla” and “Shin Ultraman,” which Anno co-created with director/co-writer/special-effects supervisorShinji Higuchi. “Shin Kamen Rider” looks like the cheapest (to make) of the three movies, so this much unusual style might initially seem more like a bug than a feature. Eventually, this outstanding reboot’s most generic elements appear subordinate to the title character’s der
# ...

# %%
import time
def compile_reviews_details(movie_list):
    """Create complete reviews for movies."""
    
    compiled_reviews = []
    
    for review_stub in movie_list:
        details = collect_ebert_review_details(review_stub['url'])
        review_stub.update(details)
        compiled_reviews.append(review_stub)
        
        time.sleep(10)
        
    return compiled_reviews

# %%
compile_reviews_details(movie_list)
# Out:
# [{'title': 'Blue Jean',
#   'author': 'Monica Castillo',
#   'url': 'https://www.rogerebert.com/reviews/blue-jean-movie-review-2023',
#   'score': 3.5,
# ...

# %%
compiled_reviews = _

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(compiled_reviews)

# %%
df.review_text
# Out:
# 0     Jean (Rosy McEwen) is dying her hair blonde on...
# 1     With “Air,” “Tetris,” and “BlackBerry,” the la...
# 2     It’s still a movie about giant space robots ta...
# 3     A group of lifelong friends gathers together a...
# 4     It takes a moment for the Japanese superhero a...
# 5     To be Black is to acknowledge the intrinsic im...
# 6     “What Dali has done and what he has imagined i...
# 7     “There’s more great literature written about f...
# 8     AlthoughVadim Perelman’s “Persian Lessons” is ...
# 9     A small-town period piece set between World Wa...
# 10    Ocean waves crashing in slow motion. Solar pan...
# 11    Although it's being sold as aLeBron Jamesbiopi...
# 12    Take one part “A Beautiful Mind.” Add a few da...
# 13    The bittersweet Korean drama “Aloners” works b...
# 14    Reviewing the Pink Floyd albumWish You Were He...
# 15    The fawning docuseries “Arnold” repackagesArno...
# 16    One of the most spectacular and frustrating mi...
# ...
